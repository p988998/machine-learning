# %%
import numpy as np

# %%
# 定义向量
x = np.array([2, 5, 8])
print(x)
print(x.shape)
# Out:
# [2 5 8]
# (3,)

# %%
# 1. 向量转置
print(x.T)
print(x.T.shape)
# Out:
# [2 5 8]
# (3,)

# %%
# 2. 相加
y = np.array([1, 3, 7])
print(x + y)
# Out:
# [ 3  8 15]

# %%
# 3. 向量与标量相乘
print(x * 3)
# Out:
# [ 6 15 24]

# %%
# 4. 向量与向量相乘（对应位置元素相乘）
print(x * y)
# Out:
# [ 2 15 56]

# %%
# 5. 向量点乘
np.dot(x, y)
print(x.dot(y))
# Out:
# 73

# %%
print(x @ y)
# Out:
# 73

# %%
# 6. 计算范数
l0_norm = np.linalg.norm(x, ord=0)
print(l0_norm)
# Out:
# 3.0

# %%
l2_norm = np.linalg.norm(x, ord=2)
print(l2_norm)
# Out:
# 9.643650760992955
